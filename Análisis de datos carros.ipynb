# %% [markdown]
# <center><img SRC="gtr.jpg"/><center>
# <h1 style="color: #0000FF"> Analisis de datos carros <h1>
# </br>
# </br>
# <p>Estaremos analizando informacion en realcion a carros. Para saber todo lo pertinente a nuestro analisis. Consta de varia data con diferente caracteristicas que evaluaremos para tomar una desicion. </p>
# </br>
#     <p>Cuando se ocupa colocar un link, se hace lo siguiente: </p> <a href="https://www.w3schools.com/cssref/css_colors.asp">W2 schools</a
# </br>
# <h2 style="color:#DC143C">1. Carga de datos y estandarizacion de la data.
# <ol>
# <li> importar librerias</li>
# <li> importar set de datos </li>
# <li> revision de los nombres de las columnas de los set de datos </li>
# <li> si tenemos mas de un archivo, vamos a unirlo en un unico dataframe </li>
# </ol>
# <h2 style="color:#00ffff">1.1 importar librerias
# </br>

# %%
#se importan las librerias pertinentes para el analisis de datos de los carros
import pandas as pd #sirve para el manejo de los datos, a travez del dataframe
import numpy as np # para el manejo de estructuras de datos - listas por ejemplo -
import matplotlib.pyplot as plt #se usa para hacer graficos.

# %% [markdown]
# <h2 style="color:#00ffff">1.2 importar set de datos </h2>
# <p>La fuente es Machine learning repository</p>
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile">fuente</a
#
#     <h2 style="color:#00ffff">1.2 importar set de datos </h2>

# %%
#se crea una lista con el nombre de las columnas
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
"compression", "horsepower", "peak", "City", "Higway", "price"]
#se cargan los datos en la memoria de la PC
df_Autos1 = pd.read_csv("autos1.csv", names = cols)
df_Autos2 = pd.read_csv("autos.csv", names = cols)

# %%
df_Autos2
# Out:
#      symboling normalized         make    fuel aspiration doors        style  \
# 0            3          ?  alfa-romero     gas        std   two  convertible
# 1            3          ?  alfa-romero     gas        std   two  convertible
# 2            1          ?  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 192          0          ?   volkswagen  diesel      turbo  four        sedan
# 193          0          ?   volkswagen     gas        std  four        wagon
# 194         -2        103        volvo     gas        std  four        sedan
# 195         -1         74        volvo     gas        std  four        wagon
# 196         -2        103        volvo     gas        std  four        sedan
#
# ...

# %%
df_Autos2.shape
# Out:
# (197, 26)

# %% [markdown]
# Este comando funciona para dar las dimensines de columnas y filas del set de datos.

# %%
df_Autos2.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# Este comando me permite --- <h2 style="color:#00ffff">1.3 Nombre de columnas </h2>

# %%
df_Autos2.head(15)
# Out:
#     symboling normalized         make fuel aspiration doors        style  \
# 0           3          ?  alfa-romero  gas        std   two  convertible
# 1           3          ?  alfa-romero  gas        std   two  convertible
# 2           1          ?  alfa-romero  gas        std   two    hatchback
# 3           2        164         audi  gas        std  four        sedan
# 4           2        164         audi  gas        std  four        sedan
# 5           2          ?         audi  gas        std   two        sedan
# 6           1        158         audi  gas        std  four        sedan
# 7           1          ?         audi  gas        std  four        wagon
# 8           1        158         audi  gas      turbo  four        sedan
# 9           0          ?         audi  gas      turbo   two    hatchback
# 10          2        192          bmw  gas        std   two        sedan
# 11          0        192          bmw  gas        std  four        sedan
# ...

# %% [markdown]
# Revision de variables

# %%
df_Autos2.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %% [markdown]
# sirve para chequear los medadatos

# %%
df_Autos2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engine-size  197 non-null    int64
#  17  system       197 non-null    object
# ...

# %% [markdown]
# <h2 style="color:#00ffff">1.4 unir set de datos </h2>

# %%
#df_Autos1 97 obs y 26 colum
#df_Autos2 197 obs y 26 colum

unionArchivos = [df_Autos1, df_Autos2]
df_Autos = pd.concat(unionArchivos)
df_Autos.shape
# Out:
# (294, 26)

# %% [markdown]
#  <h2 style="color: #FF8C00">2. Analisis de datos faltantes.
# <ol>
#     <li> identificar como se muestran los valores faltantes y estandarizarlos a NaN </li>
#     <li> contar la cantidad de valores NaN (faltantes) </li>
#     <li> analisis para imputar los valores numericos con la medida </li>
#     <li> analisis para imputar los valores caracter con el mas frecuente </li>
#     <li> eliminar con valores faltante </li>
#   </ol>
#     <h2 style="color:#FF20FF">2.1 identificar como se muestran los valores faltantes y estandarizarlos a NaN
#  </br>

# %%
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0          ?  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
# Valores faltantes: NaN(estandarizados), " ", null, ?, entre otros...

# %%
df_Autos.replace("?",np.nan,inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        NaN  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
#  <h2 style="color: #FF8C00">2. Analisis de datos faltantes.
# <ol>
#      <li> 2.2 contar la cantidad de valores NaN (faltantes) </li>

# %%
valoresperdidos = df_Autos.isnull()
valoresperdidos.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False       False  False  False       False  False  False   False
# 1      False       False  False  False       False  False  False   False
# 2      False       False  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False       False  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False       False  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# ...

# %%
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    237
# True      57
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    292
# True       2
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# ...

# %% [markdown]
# <h2 style="color: #FF8C00">2. Analisis de datos faltantes.
# <ol>
#      <li> 2.3 analisis para imputar los valores numericos con la medida  </li>

# %%
avg_norm = df_Autos["normalized"].astype("float").mean(axis=0)
print ("La media de normalized es:", avg_norm)
# Out:
# La media de normalized es: 122.26160337552743

# %%
df_Autos["normalized"].replace(np.nan, 122, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
avg_norm = df_Autos["bore"].astype("float").mean(axis=0)
print ("La media es:", avg_norm)
# Out:
# La media es: 3.341586206896553

# %%
df_Autos["bore"].replace(np.nan, 3.34, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
avg_norm = df_Autos["stroke"].astype("float").mean(axis=0)
print ("La media es:", avg_norm)
# Out:
# La media es: 3.22965517241379

# %%
df_Autos["stroke"].replace(np.nan, 3.23, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
avg_norm = df_Autos["horsepower"].astype("float").mean(axis=0)
print ("La media es:", avg_norm)
# Out:
# La media es: 103.47241379310344

# %%
df_Autos["horsepower"].replace(np.nan, 102, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
avg_norm = df_Autos["peak"].astype("float").mean(axis=0)
print ("La media es:", avg_norm)
# Out:
# La media es: 5087.931034482759

# %%
df_Autos["peak"].replace(np.nan, 5080, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
# <h2 style="color: #FF8C00">2. Analisis de datos faltantes.
# <ol>
#      <li> 2.4  analisis para imputar los valores caracter con el mas frecuente </li>

# %%
df_Autos["doors"].value_counts()
# Out:
# four    167
# two     125
# Name: doors, dtype: int64

# %%
df_Autos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df_Autos["doors"].replace(np.nan,"four", inplace=True)

# %%
valoresperdidos = df_Autos.isnull()
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    294
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    294
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# False    294
# ...

# %% [markdown]
# <h2 style="color: #FF8C00">2. Analisis de datos faltantes.
# <ol>
#      <li> 2.5 eliminar con valores faltante  </li>

# %%
df_Autos.dropna(subset = ("price"), axis=0, inplace=True)
df_Autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 192          0        122  volkswagen  diesel      turbo  four      sedan
# 193          0        122  volkswagen     gas        std  four      wagon
# 194         -2        103       volvo     gas        std  four      sedan
# 195         -1         74       volvo     gas        std  four      wagon
# 196         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_Autos.reset_index(drop=True, inplace=True)
df_Autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 284          0        122  volkswagen  diesel      turbo  four      sedan
# 285          0        122  volkswagen     gas        std  four      wagon
# 286         -2        103       volvo     gas        std  four      sedan
# 287         -1         74       volvo     gas        std  four      wagon
# 288         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %% [markdown]
# <h2 style="color: #FF8C00">3. Estandrizacion de datos.
# <ol>
#      <li> 3.1 verificacion del dominio de las variables  </li>

# %%
df_Autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors      style wheels  \
# 0          0        106  nissan  gas        std  four      sedan    fwd
# 1          0        128  nissan  gas        std  four      sedan    fwd
# 2          0        108  nissan  gas        std  four      wagon    fwd
# 3          0        108  nissan  gas        std  four      sedan    fwd
# 4          3        194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4  front   91.3  ...          181    mpfi  3.43    3.27         9.0
#
#   horsepower  peak City Higway  price
# 0         97  5200   27     34   9549
# 1        152  5200   17     22  13499
# ...

# %%
df_Autos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
df_Autos[['bore','stroke','peak']] = df_Autos[['bore','stroke','peak']].astype('float')
df_Autos[['normalized','horsepower']] = df_Autos[['normalized','horsepower']].astype('int')
df_Autos[['price']] = df_Autos[['price']].astype('float')
df_Autos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int32
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h2 style="color: #FF8C00">3. Estandrizacion de datos.
# <ol>
#      <li> 3.2 estandarizacion de valores  </li>

# %%
df_Autos["City-L/100km"] = 265/df_Autos["City"]
df_Autos["Higway-L/100km"] = 265/df_Autos["Higway"]
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  bore  stroke  compression  horsepower    peak City  \
# 0  front   97.2  ...  3.33    3.47          8.5          97  5200.0   27
# 1  front  100.4  ...  3.43    3.27          9.0         152  5200.0   17
# 2  front  100.4  ...  3.43    3.27          9.0         152  5200.0   17
# 3  front  100.4  ...  3.43    3.27          9.0         152  5200.0   19
# 4  front   91.3  ...  3.43    3.27          9.0         160  5200.0   19
#
#    Higway    price  City-L/100km  Higway-L/100km
# ...

# %% [markdown]
# <h2 style="color: #FF8C00">3. Estandrizacion de datos.
# <ol>
#      <li> 3.3 Normalizar valores  </li>

# %%
dftemp = df_Autos[['length','width','heingt']]
dftemp
# Out:
#      length  width  heingt
# 0     173.4   65.2    54.7
# 1     181.7   66.5    55.1
# 2     184.6   66.5    56.1
# 3     184.6   66.5    55.1
# 4     170.7   67.9    49.7
# ..      ...    ...     ...
# 284   180.2   66.9    55.1
# 285   183.1   66.9    55.1
# 286   188.8   67.2    56.2
# 287   188.8   67.2    57.5
# 288   188.8   67.2    56.2
#
# [289 rows x 3 columns]

# %%
df_Autos["length"] = df_Autos["length"]/df_Autos['length'].max()
df_Autos["width"] = df_Autos["width"]/df_Autos['width'].max()
df_Autos["heingt"] = df_Autos["heingt"]/df_Autos['heingt'].max()

# %%
dftemp = df_Autos[['length','width','heingt']]
dftemp
# Out:
#        length     width    heingt
# 0    0.833253  0.905556  0.914716
# 1    0.873138  0.923611  0.921405
# 2    0.887074  0.923611  0.938127
# 3    0.887074  0.923611  0.921405
# 4    0.820279  0.943056  0.831104
# ..        ...       ...       ...
# 284  0.865930  0.929167  0.921405
# 285  0.879865  0.929167  0.921405
# 286  0.907256  0.933333  0.939799
# 287  0.907256  0.933333  0.961538
# 288  0.907256  0.933333  0.939799
#
# [289 rows x 3 columns]

# %% [markdown]
# <h2 style="color: #FF8C00">3. Estandrizacion de datos.
# <ol>
#      <li> 3.4 binning  </li>

# %%
df_Autos
# Out:
#      symboling  normalized        make    fuel aspiration doors      style  \
# 0            0         106      nissan     gas        std  four      sedan
# 1            0         128      nissan     gas        std  four      sedan
# 2            0         108      nissan     gas        std  four      wagon
# 3            0         108      nissan     gas        std  four      sedan
# 4            3         194      nissan     gas        std   two  hatchback
# ..         ...         ...         ...     ...        ...   ...        ...
# 284          0         122  volkswagen  diesel      turbo  four      sedan
# 285          0         122  volkswagen     gas        std  four      wagon
# 286         -2         103       volvo     gas        std  four      sedan
# 287         -1          74       volvo     gas        std  four      wagon
# 288         -2         103       volvo     gas        std  four      sedan
#
# ...

# %%
df_Autos[['horsepower']] = df_Autos[['horsepower']].astype('int')

# %%
df_Autos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engine-size         int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower          int32
# peak              float64
# City                int64
# Higway              int64
# price             float64
# City-L/100km      float64
# Higway-L/100km    float64
# dtype: object

# %%
bins = np.linspace(min(df_Autos["horsepower"]), max(df_Autos["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
nombre = ["pequeño", "mediano", "grande"]
df_Autos["horsepower-bins"] = pd.cut(df_Autos["horsepower"], bins, labels=nombre, include_lowest=True) 
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# ...

# %%
df_Autos[["horsepower", "horsepower-bins"]].head(10)
# Out:
#    horsepower horsepower-bins
# 0          97         pequeño
# 1         152         mediano
# 2         152         mediano
# 3         152         mediano
# 4         160         mediano
# 5         200          grande
# 6         160         mediano
# 7          97         pequeño
# 8          95         pequeño
# 9          97         pequeño

# %%
df_Autos[["horsepower-bins"]].value_counts()
# Out:
# horsepower-bins
# pequeño            227
# mediano             53
# grande               9
# dtype: int64

# %%
plt.hist(df_Autos["horsepower-bins"])
plt.xlabel("cantegorias")
plt.ylabel("cantidades")
plt.title("cantidad de autos segun caballos de fuerza")
# Out:
# Text(0.5, 1.0, 'cantidad de autos segun caballos de fuerza')

# %% [markdown]
# <h2 style="color: #FF8C00">4. Visualizacion de datos.
# <ol>
#      <li> 4.1 Graficos  </li>

# %%
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# ...

# %%
#Agrupar asignaciones segun marca de vehiculo
gf1 = df_Autos.groupby(['make']).count()
gf1 = gf1.iloc[:, :1]
gf1
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                25
# peugot                22
# plymouth              14
# porsche                8
# renault                4
# saab                  12
# subaru                24
# toyota                64
# volkswagen            24
# volvo                  6

# %%
marcas = ("alfa-romeo", "audi", "bmw","chevrolet", "dodge", "honda", "isuzu0", "jaguar", "mazda", "Merecedez", "mercury", "mitsubishi", "nissan", 
          "peugot", "plymounth", "porshe", "renault", "saab", "subaru", "toyota", "volkswagen", "volvo")

eje_y = gf1['symboling'].tolist()

plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(len(marcas))

ax.barh(y_pos, eje_y, align='center',height=0.8, color= "#006400", alpha=1)

ax.set_yticks(y_pos, labels=marcas)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Cantidad de Vehiculos').set_color("#006400")
ax.set_title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf2 = df_Autos.groupby(['horsepower-bins']).count()
gf2 = gf2.iloc[:,:1]
gf2
# Out:
#                  symboling
# horsepower-bins
# pequeño                227
# mediano                 53
# grande                   9

# %%
marcas = ("Pequeno", "Mediano","Grande")

eje_y = gf2['symboling'].tolist()

#Creamos la grafica
plt.bar(marcas, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("Marca de Vehiculos")

##Titulo del Grafico
plt.title('cantidad de autos segun HP')

plt.show()

# %%
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# ...

# %%
#Agrupar asignaciones segun marca de vehiculo
gf4 = df_Autos.groupby(['doors']).count()
gf4 = gf4.iloc[:, :1]
gf4
# Out:
#        symboling
# doors
# four         168
# two          121

# %%
etiquetas = gf4.index.tolist()
sizes = gf4["symboling"].tolist()
 
separacion = (0, 0.1)  
 
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=separacion, labels=etiquetas, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal') 
 
plt.show()

# %%
#Agrupar asignaciones segun marca de vehiculo
gf5 = df_Autos.groupby(['style']).count()
gf5 = gf5.iloc[:, :1]
gf5
# Out:
#              symboling
# style
# convertible          9
# hardtop             13
# hatchback           98
# sedan              129
# wagon               40

# %%
fig, ax = plt.subplots(figsize=(9, 3), subplot_kw=dict(aspect="equal"))
 
data = gf5['symboling'].tolist()
estilo = gf5.index.tolist()
 
def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)
 

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
 
ax.legend(wedges, estilo,
          title="Estilos",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
 
plt.setp(autotexts, size=5, weight="bold")
 
ax.set_title("Porcentaje de vehiculos segun estilo")
 
plt.show()

# %%
# Colores del grafico: FFB85F FF7A5A 00AAA0 8ED2C9 FCF4D9
colores = ['#FFB85F', '#FF7A5A', '#00AAA0', '#8ED2C9', '#FCF4D9']
#Separaciones
separacion = (0.07,0.07,0.07,0.07,0.07)
#Creacion graficca circular
plt.pie(data, explode=separacion, labels=estilo, autopct='%1.1f%%',pctdistance=0.85, colors=colores)
 
#Dibujar Circulo Blanco
circulo = plt.Circle((0,0), 0.75, fc='white')
fig = plt.gcf()
fig.gca().add_artist(circulo)
 
plt.title("Porcentaje de vehiculos segun estilo")
 
plt.show()

# %%
df_Autos[["price", "City-L/100km"]].head(5)
# Out:
#      price  City-L/100km
# 0   9549.0      9.814815
# 1  13499.0     15.588235
# 2  14399.0     15.588235
# 3  13499.0     13.947368
# 4  17199.0     13.947368

# %%
import matplotlib.cbook as cbook
 
fig, ax = plt.subplots()
ax.scatter(df_Autos['price'], df_Autos['City-L/100km'], alpha=0.5)


ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo Combustible en Ciudad", fontsize=15)
ax.set_title('Correlacion Precio vrs Consumo de Combustible en Ciudad')
 
ax.grid(True)
fig.tight_layout()
 
plt.show()

# %%
import matplotlib.cbook as cbook
 
fig, ax = plt.subplots()
ax.scatter(df_Autos['price'], df_Autos['City-L/100km'],s=df_Autos['horsepower'], alpha=0.5)
#ax.scatter(df_Autos['price'], df_Autos['horsepower-bins'],alpha=0.5)
ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo Combustible en Ciudad", fontsize=15)
ax.set_title('Correlacion Precio vrs Consumo de Combustible en Ciudad')
 
ax.grid(True)
fig.tight_layout()
 
plt.show()
